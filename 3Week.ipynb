# %% [markdown]
# # URL : https://school.programmers.co.kr/learn/courses/30/lessons/42577

# %% [markdown]
# ## 전화번호 목록

# %% [markdown]
# ## 우수답안

# %%
def solution(phoneBook):
    phoneBook = sorted(phoneBook)

    for p1, p2 in zip(phoneBook, phoneBook[1:]):
        if p2.startswith(p1):
            return False
    return True

# %%
phoneBook = ["119", "97674223", "1195524421"]
for p1, p2 in zip(phoneBook, phoneBook[1:]):
    print(p1, p2)
    
    
print('###')
for a in phoneBook:
    print(a)
# Out:
# 119 97674223
# 97674223 1195524421
# ###
# 119
# 97674223
# 1195524421

# %%
a = '123456'
b = '123'
c = '74393'
a.startswith(b)
# Out:
# False

# %% [markdown]
# ## 조성민

# %%
def solution(phone_book):
    phone_book.sort()
    
    for i in range(len(phone_book)-1):
        if len(phone_book[i]) < len(phone_book[i+1]):
            if phone_book[i+1][:len(phone_book[i])] == phone_book[i]:
                return False
    
    return True

# %%
a = ["119", "97674223", "1195524421"]
a.sort()
for i in range(len(a) - 1):
    if len(a[i]) < len(a[i+1]):
        if a[i+1][:len(a[i])] == a[i]:
            return False
return True
# Out:
# 0
# 1

# %%
["119", "97674223", "1195524421"]

# %% [markdown]
# ## 심경민

# %% [markdown]
# ### 멸망하지 말아요 ㅎㅎ

# %% [markdown]
# ![image.png](attachment:image.png)

# %%
def solution(phone_book):
    for i in range(len(phone_book)-1):
        a = phone_book[i]
        b = phone_book[i+1]
        
        A = len(a)-1
        B = len(b)-1
        
        if A <= B:
            if a == b[:A]:
                return False
        else:
            if b == a[:B]:
                return False
    return True

# %% [markdown]
# ## 이선우

# %% [markdown]
# ### 참  잘했어요 ~~

# %%
def solution(phone_book):
    
    for i in phone_book:
        word=''
        for j in i:
            word += j
            if word != i and word in phone_book:
                return False
    return True

# %% [markdown]
# ## 이민우

# %% [markdown]
# ### 틀렸지만 다음문제 잘했으니 패스~

# %%
def solution(phone_book):
    if len(phone_book) <= 0:
        return []
    else:
        for i in range(phone_book)
        a = [phone_book[0]]
        b = solution(phone_book[1:])
        
    if int(a)/int(b[0][:len(a)])==1:
            return False
        else:
            return True
# Out:
#   File "<tokenize>", line 11
#     else:
#     ^
# IndentationError: unindent does not match any outer indentation level

# %% [markdown]
# ## Test

# %%
a = ["119", "97674223", "1195524421"]
a.sort()
a
# Out:
# ['119', '1195524421', '97674223']

# %%
print(solution(["119", "97674223", "1195524421"]))
print(solution(["123","456","789"]))
print(solution(["12","123","1235","567","88"]))
# Out:
# True
# True
# True

# %% [markdown]
# # URL : https://school.programmers.co.kr/learn/courses/30/lessons/42578

# %% [markdown]
# ## 위장

# %% [markdown]
# ## 모범 답안

# %%
def solution(clothes):
    from collections import Counter
    from functools import reduce
    cnt = Counter([kind for name, kind in clothes])
    answer = reduce(lambda x, y: x*(y+1), cnt.values(), 1) - 1
    return answer

# %%
clothes = [["yellow_hat", "headgear"], ["blue_sunglasses", "eyewear"], ["green_turban", "headgear"]]

from collections import Counter
from functools import reduce
cnt = Counter([kind for name, kind in clothes])
cnt
Counter(['a', 'b', 'c', 'b'])
Counter({'a': 1, 'b': 2, 'c': 1})
# Out:
# Counter({'a': 1, 'b': 2, 'c': 1})

# %% [markdown]
# ## 조성민

# %%
def solution(clothes):
    clo_dict = {}
    clo_num = len(clothes)
    for cloth, key in clothes:
        clo_dict[key] = 0
        
    for cloth, key in clothes:
        clo_dict[key] += 1
        
    if len(clo_dict) == 1:
        return clo_num
    
    i = 1
    for num in clo_dict.values():
        i *= (num + 1)
        
    return i-1

# %%
print(solution([["yellow_hat", "headgear"], ["blue_sunglasses", "eyewear"], ["green_turban", "headgear"]]))
print(solution([["crow_mask", "face"], ["blue_sunglasses", "face"], ["smoky_makeup", "face"]]))
# Out:
# 5
# 3

# %% [markdown]
# ## 심경민

# %% [markdown]
# ### 한숨...쉬지말고 할 수 있습니다~!

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)

# %%
def solution(clothes):
    for i in range(1, len(clothes)):
        for k in range(i):
            if clothes[i][1] == clothes[k][1]:
                return len(clothes)
            else:
# Out:
#   File "C:\Users\smcho\AppData\Local\Temp/ipykernel_38008/2501095822.py", line 6
#     else:
#          ^
# IndentationError: expected an indented block

# %% [markdown]
# ## 이선우

# %% [markdown]
# ### 못풀었지만 괜찮아요

# %%
def solution(clothes):
    b=[]
    for i in clothes:
        b.append(i[1])
    b =list(set(b))
    if len(b)==1:
        return len(clothes)
    return len(clothes)+len(b)

# %% [markdown]
# ## 이민우

# %% [markdown]
# ### 민우의 자존심

# %%
def solution(clothes):
    clo_dict = {}
    clo_num = len(clothes)
    for cloth, key in clothes:
        clo_dict[key] = 0
        
    for cloth, key in clothes:
        clo_dict[key] += 1
        
    if len(clo_dict) == 1:
        return clo_num
    
    i = 1
    for num in clo_dict.values():
        if num == 1:
            i *= num*2
            
        else:
            i *= 2 ** num - (2 ** num - num - 1)
        
    return i - 1

# %% [markdown]
# ## Test

# %%
print(solution([["yellow_hat", "headgear"], ["blue_sunglasses", "eyewear"], ["green_turban", "headgear"]]))
print(solution([["crow_mask", "face"], ["blue_sunglasses", "face"], ["smoky_makeup", "face"]]))
# Out:
# 5
# 3
